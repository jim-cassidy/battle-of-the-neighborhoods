# %% [markdown]
# <a href="https://cognitiveclass.ai"><img src = "https://ibm.box.com/shared/static/9gegpsmnsoo25ikkbl4qzlvlyjbgxs5x.png" width = 400> </a>
#
# <h1 align=center><font size = 5>Learning FourSquare API with Python</font></h1>

# %% [markdown]
# ## Introduction
#
# In this lab, you will learn in details how to make calls to the Foursquare API for different purposes. You will learn how to construct a URL to send a request to the API to search for a specific type of venues, to explore a particular venue, to explore a Foursquare user, to explore a geographical location, and to get trending venues around a location. Also, you will learn how to use the visualization library, Folium, to visualize the results.

# %% [markdown]
# ## Table of Contents
#
# 1. <a href="#item1">Foursquare API Search Function</a>
# 2. <a href="#item2">Explore a Given Venue</a>
# 3. <a href="#item3">Explore a User</a>
# 4. <a href="#item4">Foursquare API Explore Function</a>
# 5. <a href="#item5">Get Trending Venues</a>

# %% [markdown]
# ### Import necessary Libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
# Out:
# Collecting package metadata: done
# Solving environment: done
#
# # All requested packages already installed.
#
# Collecting package metadata: done
# Solving environment: done
#
# # All requested packages already installed.
#
# Folium installed

# %% [markdown]
# ### Define Foursquare Credentials and Version

# %% [markdown]
# ##### Make sure that you have created a Foursquare developer account and have your credentials handy

# %%
CLIENT_ID = 'JAH2Y0HES01BIMCMSRULSHTXIVUYLOQPGNJBIC0LWJ4KWMUL' # your Foursquare ID
CLIENT_SECRET = 'GEZ1UJJVLK5YIXKZPMG03UBNBYHMJPA52NAEDO1GSP5IL1PA' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 1000
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: JAH2Y0HES01BIMCMSRULSHTXIVUYLOQPGNJBIC0LWJ4KWMUL
# CLIENT_SECRET:GEZ1UJJVLK5YIXKZPMG03UBNBYHMJPA52NAEDO1GSP5IL1PA

# %% [markdown]
# #### Let's again assume that you are staying at the Conrad hotel. So let's start by converting the Contrad Hotel's address to its latitude and longitude coordinates.

# %% [markdown]
# In order to define an instance of the geocoder, we need to define a user_agent. We will name our agent <em>foursquare_agent</em>, as shown below.

# %%
address = 'Newark, NJ'
CID = '4bf58dd8d48988d13d941735'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 40.735657 -74.1723667

# %% [markdown]
# <a id="item1"></a>

# %% [markdown]
# ## 1. Search for a specific venue category
# > `https://api.foursquare.com/v2/venues/`**search**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**`&query=`**QUERY**`&radius=`**RADIUS**`&limit=`**LIMIT**

# %% [markdown]
# #### Now, let's assume that it is lunch time, and you are craving Italian food. So, let's define a query to search for Italian food that is within 500 metres from the Conrad Hotel.

# %%
search_query = 'McDonalds'
radius = 1000
print(search_query + ' .... OK!')
# Out:
# McDonalds .... OK!

# %% [markdown]
# #### Define the corresponding URL

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=JAH2Y0HES01BIMCMSRULSHTXIVUYLOQPGNJBIC0LWJ4KWMUL&client_secret=GEZ1UJJVLK5YIXKZPMG03UBNBYHMJPA52NAEDO1GSP5IL1PA&ll=40.735657,-74.1723667&v=20180604&query=McDonalds&radius=1000&limit=1000'

# %% [markdown]
# #### Send the GET Request and examine the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c63e17b4c1f6764eb655509'},
#  'response': {'venues': [{'id': '4dbed70dbd41634086125ba1',
#     'name': "McDonald's",
#     'location': {'address': '7944 Penn Station',
#      'lat': 40.734896,
#      'lng': -74.164231,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.734896,
#        'lng': -74.164231}],
#      'distance': 691,
#      'postalCode': '07102',
#      'cc': 'US',
#      'city': 'Newark',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['7944 Penn Station',
#       'Newark, NJ 07102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550049659',
#     'hasPerk': False},
#    {'id': '4bba72bf7421a593ead3c340',
#     'name': "McDonald's",
#     'location': {'address': '561 McCarter Hwy',
#      'lat': 40.72667133119432,
#      'lng': -74.1732582449913,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.72667133119432,
#        'lng': -74.1732582449913}],
#      'distance': 1003,
#      'postalCode': '07102',
#      'cc': 'US',
#      'city': 'Newark',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['561 McCarter Hwy',
#       'Newark, NJ 07102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550049659',
#     'hasPerk': False},
#    {'id': '4c3cec1aa9509c74c253395b',
#     'name': "McDonald's",
#     'location': {'address': '772 Broad St',
#      'lat': 40.7359416,
#      'lng': -74.1716398,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7359416,
#        'lng': -74.1716398}],
#      'distance': 69,
#      'postalCode': '07102',
#      'cc': 'US',
#      'city': 'Newark',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['772 Broad St',
#       'Newark, NJ 07102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550049659',
#     'hasPerk': False},
#    {'id': '586679e69900e60f75e8bfc8',
#     'name': "McDonald's",
#     'location': {'lat': 40.735291,
#      'lng': -74.186076,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.735291,
#        'lng': -74.186076}],
#      'distance': 1157,
#      'cc': 'US',
#      'city': 'Newark',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['Newark, NJ', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550049659',
#     'hasPerk': False},
#    {'id': '4fc80ecce4b047cf1b16abf8',
#     'name': 'Mcgoogle Box',
#     'location': {'lat': 40.73385407234026,
#      'lng': -74.17105908383428,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.73385407234026,
#        'lng': -74.17105908383428}],
#      'distance': 229,
#      'postalCode': '07102',
#      'cc': 'US',
#      'city': 'Newark',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['Newark, NJ 07102', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e5931735',
#       'name': 'Music Venue',
#       'pluralName': 'Music Venues',
#       'shortName': 'Music Venue',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550049659',
#     'hasPerk': False},
#    {'id': '4f2ac11ee4b07e41d98cc2e2',
#     'name': 'M.C. Dean, Inc',
#     'location': {'address': 'Loudoun Gateway IV',
#      'lat': 40.734471,
#      'lng': -74.166785,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.734471,
#        'lng': -74.166785}],
#      'distance': 488,
#      'postalCode': '07102',
#      'cc': 'US',
#      'city': 'Sterling',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['Loudoun Gateway IV',
#       'Sterling, NJ 07102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550049659',
#     'hasPerk': False},
#    {'id': '4b99212af964a5205b6335e3',
#     'name': 'McWhorter Barbeque',
#     'location': {'address': '104 McWhorter St',
#      'crossStreet': 'at Green St',
#      'lat': 40.72968479780227,
#      'lng': -74.1668165968862,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.72968479780227,
#        'lng': -74.1668165968862}],
#      'distance': 813,
#      'postalCode': '07105',
#      'cc': 'US',
#      'city': 'Newark',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['104 McWhorter St (at Green St)',
#       'Newark, NJ 07105',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550049659',
#     'hasPerk': False},
#    {'id': '4da0997131a6b60c6fff7618',
#     'name': 'McElroy, Deutsch, Mulvaney & Carpenter, LLP',
#     'location': {'address': '100 Mulberry St #3',
#      'crossStreet': 'at Market St',
#      'lat': 40.73554131144134,
#      'lng': -74.16742978544212,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.73554131144134,
#        'lng': -74.16742978544212}],
#      'distance': 416,
#      'postalCode': '07102',
#      'cc': 'US',
#      'city': 'Newark',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['100 Mulberry St #3 (at Market St)',
#       'Newark, NJ 07102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550049659',
#     'hasPerk': False},
#    {'id': '50578052e4b0ed8a09af149e',
#     'name': 'McCarter Highway',
#     'location': {'lat': 40.73062629887187,
#      'lng': -74.1692473102503,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.73062629887187,
#        'lng': -74.1692473102503}],
#      'distance': 618,
#      'postalCode': '07102',
#      'cc': 'US',
#      'city': 'Newark',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['Newark, NJ 07102', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f9931735',
#       'name': 'Road',
#       'pluralName': 'Roads',
#       'shortName': 'Road',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/highway_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550049659',
#     'hasPerk': False},
#    {'id': '4cd2e51ffa66236ab8aded2e',
#     'name': 'Law Office of John P McGovern',
#     'location': {'address': '221 Washington St',
#      'crossStreet': 'Bank St',
#      'lat': 40.737526288533566,
#      'lng': -74.17459084478702,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.737526288533566,
#        'lng': -74.17459084478702}],
#      'distance': 280,
#      'postalCode': '07102',
#      'cc': 'US',
#      'city': 'Newark',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['221 Washington St (Bank St)',
#       'Newark, NJ 07102',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b3f',
#       'name': 'Lawyer',
#       'pluralName': 'Lawyers',
#       'shortName': 'Lawyer',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lawschool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550049659',
#     'hasPerk': False},
#    {'id': '4c8c1a0bf0ce236af73a15ef',
#     'name': 'Mcwhorters',
#     'location': {'address': 'McWhorter ave',
#      'lat': 40.730253741212856,
#      'lng': -74.16830128220722,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.730253741212856,
#        'lng': -74.16830128220722}],
#      'distance': 692,
#      'cc': 'US',
#      'city': 'Newark',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['McWhorter ave', 'Newark, NJ', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d12d951735',
#       'name': 'Boat or Ferry',
#       'pluralName': 'Boats or Ferries',
#       'shortName': 'Boat / Ferry',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/boat_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550049659',
#     'hasPerk': False},
#    {'id': '4d02a799e350b60c813a7842',
#     'name': 'McCarter & English LLP',
#     'location': {'address': '100 Mulberry St',
#      'crossStreet': 'at Clinton St.',
#      'lat': 40.73544176828675,
#      'lng': -74.16910263514686,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.73544176828675,
#        'lng': -74.16910263514686}],
#      'distance': 276,
#      'postalCode': '07102',
#      'cc': 'US',
#      'city': 'Newark',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['100 Mulberry St (at Clinton St.)',
#       'Newark, NJ 07102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550049659',
#     'hasPerk': False},
#    {'id': '4de04c82fa76425c54163e25',
#     'name': 'McWhorter St.',
#     'location': {'lat': 40.729493819829464,
#      'lng': -74.1698607925261,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.729493819829464,
#        'lng': -74.1698607925261}],
#      'distance': 717,
#      'postalCode': '07102',
#      'cc': 'US',
#      'city': 'Newark',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['Newark, NJ 07102', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f9931735',
#       'name': 'Road',
#       'pluralName': 'Roads',
#       'shortName': 'Road',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/highway_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550049659',
#     'hasPerk': False},
#    {'id': '4edd4ff077c8274e009cc39b',
#     'name': 'Mccarter & Bridge Street',
#     'location': {'lat': 40.74490664400917,
#      'lng': -74.1669883019677,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74490664400917,
#        'lng': -74.1669883019677}],
#      'distance': 1125,
#      'postalCode': '07029',
#      'cc': 'US',
#      'city': 'Harrison',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['Harrison, NJ 07029', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f9931735',
#       'name': 'Road',
#       'pluralName': 'Roads',
#       'shortName': 'Road',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/highway_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550049659',
#     'hasPerk': False},
#    {'id': '4ea6f00d5c5c6cec793346f7',
#     'name': 'Eminent Properties 301 Mcarter Hwy',
#     'location': {'lat': 40.73147783007096,
#      'lng': -74.16849048820143,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.73147783007096,
#        'lng': -74.16849048820143}],
#      'distance': 568,
#      'cc': 'US',
#      'city': 'Newark',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['Newark, NJ', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550049659',
#     'hasPerk': False},
#    {'id': '4af11500f964a520b0e021e3',
#     'name': "McGovern's Tavern",
#     'location': {'address': '58 New St',
#      'crossStreet': 'btwn Halsey St. and Washington St.',
#      'lat': 40.740405224231516,
#      'lng': -74.17221793735169,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.740405224231516,
#        'lng': -74.17221793735169}],
#      'distance': 528,
#      'postalCode': '07102',
#      'cc': 'US',
#      'city': 'Newark',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['58 New St (btwn Halsey St. and Washington St.)',
#       'Newark, NJ 07102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1550049659',
#     'hasPerk': False}]}}

# %% [markdown]
# #### Get relevant part of JSON and transform it into a *pandas* dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...    False
# 1  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...    False
# 2  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...    False
# 3  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...    False
# 4  [{'id': '4bf58dd8d48988d1e5931735', 'name': 'M...    False
#
#                          id   location.address location.cc location.city  \
# 0  4dbed70dbd41634086125ba1  7944 Penn Station          US        Newark
# 1  4bba72bf7421a593ead3c340   561 McCarter Hwy          US        Newark
# 2  4c3cec1aa9509c74c253395b       772 Broad St          US        Newark
# 3  586679e69900e60f75e8bfc8                NaN          US        Newark
# 4  4fc80ecce4b047cf1b16abf8                NaN          US        Newark
#
#   location.country location.crossStreet  location.distance  \
# 0    United States                  NaN                691
# 1    United States                  NaN               1003
# 2    United States                  NaN                 69
# 3    United States                  NaN               1157
# 4    United States                  NaN                229
#
#                            location.formattedAddress  \
# 0  [7944 Penn Station, Newark, NJ 07102, United S...
# 1  [561 McCarter Hwy, Newark, NJ 07102, United St...
# 2    [772 Broad St, Newark, NJ 07102, United States]
# 3                        [Newark, NJ, United States]
# 4                  [Newark, NJ 07102, United States]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 40.734896, 'lng':...     40.734896
# 1  [{'label': 'display', 'lat': 40.72667133119432...     40.726671
# 2  [{'label': 'display', 'lat': 40.7359416, 'lng'...     40.735942
# 3  [{'label': 'display', 'lat': 40.735291, 'lng':...     40.735291
# 4  [{'label': 'display', 'lat': 40.73385407234026...     40.733854
#
#    location.lng location.postalCode location.state          name    referralId
# 0    -74.164231               07102             NJ    McDonald's  v-1550049659
# 1    -74.173258               07102             NJ    McDonald's  v-1550049659
# 2    -74.171640               07102             NJ    McDonald's  v-1550049659
# 3    -74.186076                 NaN             NJ    McDonald's  v-1550049659
# 4    -74.171059               07102             NJ  Mcgoogle Box  v-1550049659

# %% [markdown]
# #### Define information of interest and filter dataframe

# %%
dataframe
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                            name            categories  \
# 0                                    McDonald's  Fast Food Restaurant
# 1                                    McDonald's  Fast Food Restaurant
# 2                                    McDonald's  Fast Food Restaurant
# 3                                    McDonald's  Fast Food Restaurant
# 4                                  Mcgoogle Box           Music Venue
# 5                                M.C. Dean, Inc                Office
# 6                            McWhorter Barbeque             BBQ Joint
# 7   McElroy, Deutsch, Mulvaney & Carpenter, LLP                Office
# 8                              McCarter Highway                  Road
# 9                 Law Office of John P McGovern                Lawyer
# 10                                   Mcwhorters         Boat or Ferry
# 11                       McCarter & English LLP                Office
# 12                                McWhorter St.                  Road
# 13                     Mccarter & Bridge Street                  Road
# 14           Eminent Properties 301 Mcarter Hwy                Office
# 15                            McGovern's Tavern                   Bar
#
#                address  cc      city        country  \
# 0    7944 Penn Station  US    Newark  United States
# 1     561 McCarter Hwy  US    Newark  United States
# 2         772 Broad St  US    Newark  United States
# 3                  NaN  US    Newark  United States
# 4                  NaN  US    Newark  United States
# 5   Loudoun Gateway IV  US  Sterling  United States
# 6     104 McWhorter St  US    Newark  United States
# 7   100 Mulberry St #3  US    Newark  United States
# 8                  NaN  US    Newark  United States
# 9    221 Washington St  US    Newark  United States
# 10       McWhorter ave  US    Newark  United States
# 11     100 Mulberry St  US    Newark  United States
# 12                 NaN  US    Newark  United States
# 13                 NaN  US  Harrison  United States
# 14                 NaN  US    Newark  United States
# 15           58 New St  US    Newark  United States
#
#                            crossStreet  distance  \
# 0                                  NaN       691
# 1                                  NaN      1003
# 2                                  NaN        69
# 3                                  NaN      1157
# 4                                  NaN       229
# 5                                  NaN       488
# 6                          at Green St       813
# 7                         at Market St       416
# 8                                  NaN       618
# 9                              Bank St       280
# 10                                 NaN       692
# 11                      at Clinton St.       276
# 12                                 NaN       717
# 13                                 NaN      1125
# 14                                 NaN       568
# 15  btwn Halsey St. and Washington St.       528
#
#                                      formattedAddress  \
# 0   [7944 Penn Station, Newark, NJ 07102, United S...
# 1   [561 McCarter Hwy, Newark, NJ 07102, United St...
# 2     [772 Broad St, Newark, NJ 07102, United States]
# 3                         [Newark, NJ, United States]
# 4                   [Newark, NJ 07102, United States]
# 5   [Loudoun Gateway IV, Sterling, NJ 07102, Unite...
# 6   [104 McWhorter St (at Green St), Newark, NJ 07...
# 7   [100 Mulberry St #3 (at Market St), Newark, NJ...
# 8                   [Newark, NJ 07102, United States]
# 9   [221 Washington St (Bank St), Newark, NJ 07102...
# 10         [McWhorter ave, Newark, NJ, United States]
# 11  [100 Mulberry St (at Clinton St.), Newark, NJ ...
# 12                  [Newark, NJ 07102, United States]
# 13                [Harrison, NJ 07029, United States]
# 14                        [Newark, NJ, United States]
# 15  [58 New St (btwn Halsey St. and Washington St....
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'label': 'display', 'lat': 40.734896, 'lng':...  40.734896 -74.164231
# 1   [{'label': 'display', 'lat': 40.72667133119432...  40.726671 -74.173258
# 2   [{'label': 'display', 'lat': 40.7359416, 'lng'...  40.735942 -74.171640
# 3   [{'label': 'display', 'lat': 40.735291, 'lng':...  40.735291 -74.186076
# 4   [{'label': 'display', 'lat': 40.73385407234026...  40.733854 -74.171059
# 5   [{'label': 'display', 'lat': 40.734471, 'lng':...  40.734471 -74.166785
# 6   [{'label': 'display', 'lat': 40.72968479780227...  40.729685 -74.166817
# 7   [{'label': 'display', 'lat': 40.73554131144134...  40.735541 -74.167430
# 8   [{'label': 'display', 'lat': 40.73062629887187...  40.730626 -74.169247
# 9   [{'label': 'display', 'lat': 40.73752628853356...  40.737526 -74.174591
# 10  [{'label': 'display', 'lat': 40.73025374121285...  40.730254 -74.168301
# 11  [{'label': 'display', 'lat': 40.73544176828675...  40.735442 -74.169103
# 12  [{'label': 'display', 'lat': 40.72949381982946...  40.729494 -74.169861
# 13  [{'label': 'display', 'lat': 40.74490664400917...  40.744907 -74.166988
# 14  [{'label': 'display', 'lat': 40.73147783007096...  40.731478 -74.168490
# 15  [{'label': 'display', 'lat': 40.74040522423151...  40.740405 -74.172218
#
#    postalCode state                        id
# 0       07102    NJ  4dbed70dbd41634086125ba1
# 1       07102    NJ  4bba72bf7421a593ead3c340
# 2       07102    NJ  4c3cec1aa9509c74c253395b
# 3         NaN    NJ  586679e69900e60f75e8bfc8
# 4       07102    NJ  4fc80ecce4b047cf1b16abf8
# 5       07102    NJ  4f2ac11ee4b07e41d98cc2e2
# 6       07105    NJ  4b99212af964a5205b6335e3
# 7       07102    NJ  4da0997131a6b60c6fff7618
# 8       07102    NJ  50578052e4b0ed8a09af149e
# 9       07102    NJ  4cd2e51ffa66236ab8aded2e
# 10        NaN    NJ  4c8c1a0bf0ce236af73a15ef
# 11      07102    NJ  4d02a799e350b60c813a7842
# 12      07102    NJ  4de04c82fa76425c54163e25
# 13      07029    NJ  4edd4ff077c8274e009cc39b
# 14        NaN    NJ  4ea6f00d5c5c6cec793346f7
# 15      07102    NJ  4af11500f964a520b0e021e3

# %% [markdown]
# #### Let's visualize the Italian restaurants that are nearby

# %%
dataframe_filtered.name
# Out:
# 0                                      McDonald's
# 1                                      McDonald's
# 2                                      McDonald's
# 3                                      McDonald's
# 4                                    Mcgoogle Box
# 5                                  M.C. Dean, Inc
# 6                              McWhorter Barbeque
# 7     McElroy, Deutsch, Mulvaney & Carpenter, LLP
# 8                                McCarter Highway
# 9                   Law Office of John P McGovern
# 10                                     Mcwhorters
# 11                         McCarter & English LLP
# 12                                  McWhorter St.
# 13                       Mccarter & Bridge Street
# 14             Eminent Properties 301 Mcarter Hwy
# 15                              McGovern's Tavern
# Name: name, dtype: object

# %%
venue_id = '4bba72bf7421a593ead3c340'  
 

url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4bba72bf7421a593ead3c340?client_id=JAH2Y0HES01BIMCMSRULSHTXIVUYLOQPGNJBIC0LWJ4KWMUL&client_secret=GEZ1UJJVLK5YIXKZPMG03UBNBYHMJPA52NAEDO1GSP5IL1PA&v=20180604'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'price', 'hasMenu', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'menu', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'description', 'storeId', 'page', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'hours', 'popular', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])
# {'id': '4bba72bf7421a593ead3c340',
#  'name': "McDonald's",
#  'contact': {'phone': '9736430810',
#   'formattedPhone': '(973) 643-0810',
#   'twitter': 'mcdonalds',
#   'instagram': 'mcdonalds',
#   'facebook': '113753465323937',
#   'facebookUsername': 'McDonalds561McCarterHighway',
#   'facebookName': "McDonald's"},
#  'location': {'address': '561 McCarter Hwy',
#   'lat': 40.72667133119432,
#   'lng': -74.1732582449913,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 40.72667133119432,
#     'lng': -74.1732582449913}],
#   'postalCode': '07102',
#   'cc': 'US',
#   'city': 'Newark',
#   'state': 'NJ',
#   'country': 'United States',
#   'formattedAddress': ['561 McCarter Hwy',
#    'Newark, NJ 07102',
#    'United States']},
#  'canonicalUrl': 'https://foursquare.com/v/mcdonalds/4bba72bf7421a593ead3c340',
#  'categories': [{'id': '4bf58dd8d48988d16e941735',
#    'name': 'Fast Food Restaurant',
#    'pluralName': 'Fast Food Restaurants',
#    'shortName': 'Fast Food',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#     'suffix': '.png'},
#    'primary': True}],
#  'verified': True,
#  'stats': {'tipCount': 14},
#  'url': 'http://mcdonalds.com',
#  'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'},
#  'hasMenu': True,
#  'likes': {'count': 26,
#   'groups': [{'type': 'others', 'count': 26, 'items': []}],
#   'summary': '26 Likes'},
#  'dislike': False,
#  'ok': False,
#  'rating': 6.0,
#  'ratingColor': 'FFC800',
#  'ratingSignals': 57,
#  'menu': {'type': 'Menu',
#   'label': 'Menu',
#   'anchor': 'View Menu',
#   'url': 'https://foursquare.com/v/mcdonalds/4bba72bf7421a593ead3c340/menu',
#   'mobileUrl': 'https://foursquare.com/v/4bba72bf7421a593ead3c340/device_menu',
#   'externalUrl': 'https://www.mcdonalds.com/us/en-us/full-menu.html'},
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 19,
#   'groups': [{'type': 'checkin',
#     'name': "Friends' check-in photos",
#     'count': 0,
#     'items': []},
#    {'type': 'venue',
#     'name': 'Venue photos',
#     'count': 19,
#     'items': [{'id': '51ddca2ce4b0326a8003ee0f',
#       'createdAt': 1373489708,
#       'source': {'name': 'Instagram', 'url': 'http://instagram.com'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/4862834_juHWtaKKkDCjaEPgB04qUF0VfUwOkF19xPJvIAdMpjI.jpg',
#       'width': 612,
#       'height': 612,
#       'user': {'id': '4862834',
#        'firstName': 'Michael',
#        'lastName': 'Ona',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/GPYQTPRDWLSEWUDU.jpg'}},
#       'visibility': 'public'}]}],
#   'summary': '0 photos'},
#  'reasons': {'count': 0, 'items': []},
#  'description': "Come visit us at 561 McCarter Highway in Newark. McDonald’s is proud to have become one of the world's leading food service brands with more than 36,000 restaurants in more than 100 countries. Whether you’re looking to start your day with a McCafé® coffee or enjoy a mouthwatering Big Mac®, McDona...",
#  'storeId': '6978',
#  'page': {'pageInfo': {'links': {'count': 1,
#     'items': [{'url': 'http://mcdonalds.com'}]}},
#   'user': {'id': '89988049',
#    'firstName': "McDonald's National",
#    'gender': 'none',
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/89988049-JBDDHEOZGRA4ZS11.jpg'},
#    'type': 'chain',
#    'tips': {'count': 20},
#    'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]},
#    'homeCity': 'New York, NY',
#    'bio': '',
#    'contact': {}}},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1270510271,
#  'tips': {'count': 14,
#   'groups': [{'type': 'others',
#     'name': 'All tips',
#     'count': 14,
#     'items': [{'id': '4e9a8d61cc215f3adcd81ff8',
#       'createdAt': 1318751585,
#       'text': 'There late night drive thru is really slow.',
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/4e9a8d61cc215f3adcd81ff8',
#       'lang': 'en',
#       'likes': {'count': 1,
#        'groups': [{'type': 'others', 'count': 1, 'items': []}],
#        'summary': '1 like'},
#       'logView': True,
#       'agreeCount': 0,
#       'disagreeCount': 0,
#       'todo': {'count': 0},
#       'user': {'id': '295372',
#        'firstName': 'MJ',
#        'gender': 'female',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/Q4QCKRZ5WLTD1CQS.jpg'}}}]}]},
#  'shortUrl': 'http://4sq.com/9DpJYQ',
#  'timeZone': 'America/New_York',
#  'listed': {'count': 0,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 0,
#     'items': []}]},
#  'hours': {'status': 'Open',
#   'richStatus': {'entities': [], 'text': 'Open'},
#   'isOpen': True,
#   'isLocalHoliday': False,
#   'dayData': [],
#   'timeframes': [{'days': 'Mon–Sun',
#     'includesToday': True,
#     'open': [{'renderedTime': '24 Hours'}],
#     'segments': []}]},
#  'popular': {'isOpen': False,
#   'isLocalHoliday': False,
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': '8:00 AM–10:00 AM'},
#      {'renderedTime': 'Noon–1:00 PM'},
#      {'renderedTime': '3:00 PM–8:00 PM'},
#      {'renderedTime': '10:00 PM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Thu',
#     'open': [{'renderedTime': '8:00 AM–1:00 PM'},
#      {'renderedTime': '7:00 PM–Midnight'}],
#     'segments': []},
#    {'days': 'Fri',
#     'open': [{'renderedTime': '8:00 AM–1:00 PM'},
#      {'renderedTime': '5:00 PM–7:00 PM'},
#      {'renderedTime': '10:00 PM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Sat', 'open': [{'renderedTime': '24 Hours'}], 'segments': []},
#    {'days': 'Sun', 'open': [{'renderedTime': '24 Hours'}], 'segments': []},
#    {'days': 'Mon',
#     'open': [{'renderedTime': '8:00 AM–1:00 PM'},
#      {'renderedTime': '3:00 PM–6:00 PM'}],
#     'segments': []},
#    {'days': 'Tue',
#     'open': [{'renderedTime': '7:00 AM–10:00 AM'},
#      {'renderedTime': 'Noon–1:00 PM'}],
#     'segments': []}]},
#  'pageUpdates': {'count': 6, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'attributes': {'groups': [{'type': 'price',
#     'name': 'Price',
#     'summary': '$',
#     'count': 1,
#     'items': [{'displayName': 'Price', 'displayValue': '$', 'priceTier': 1}]},
#    {'type': 'outdoorSeating',
#     'name': 'Outdoor Seating',
#     'count': 1,
#     'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'No'}]},
#    {'type': 'serves',
#     'name': 'Menus',
#     'summary': 'Breakfast & Lunch',
#     'count': 8,
#     'items': [{'displayName': 'Breakfast', 'displayValue': 'Breakfast'},
#      {'displayName': 'Lunch', 'displayValue': 'Lunch'}]},
#    {'type': 'diningOptions',
#     'name': 'Dining Options',
#     'count': 5,
#     'items': [{'displayName': 'Delivery', 'displayValue': 'No Delivery'}]}]},
#  'bestPhoto': {'id': '51ddca2ce4b0326a8003ee0f',
#   'createdAt': 1373489708,
#   'source': {'name': 'Instagram', 'url': 'http://instagram.com'},
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/4862834_juHWtaKKkDCjaEPgB04qUF0VfUwOkF19xPJvIAdMpjI.jpg',
#   'width': 612,
#   'height': 612,
#   'visibility': 'public'},
#  'colors': {'highlightColor': {'photoId': '51ddca2ce4b0326a8003ee0f',
#    'value': -16250832},
#   'highlightTextColor': {'photoId': '51ddca2ce4b0326a8003ee0f', 'value': -1},
#   'algoVersion': 3}}

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 6.0

# %%
# Out:
# {'address': '561 McCarter Hwy',
#  'lat': 40.72667133119432,
#  'lng': -74.1732582449913,
#  'labeledLatLngs': [{'label': 'display',
#    'lat': 40.72667133119432,
#    'lng': -74.1732582449913}],
#  'postalCode': '07102',
#  'cc': 'US',
#  'city': 'Newark',
#  'state': 'NJ',
#  'country': 'United States',
#  'formattedAddress': ['561 McCarter Hwy', 'Newark, NJ 07102', 'United States']}
